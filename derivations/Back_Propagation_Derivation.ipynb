# %% [markdown]
# <a href="https://colab.research.google.com/github/lizhieffe/llm_knowledge/blob/main/derivations/Back_Propagation_Derivation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Back Prop

# %% [markdown]
# ## Main Rules for Back Prop
#
# Thinking tips
#
# - The derivative of something (A) to something else (B), put the result's dimension aside, is basially the **collection of individual element in A 's derivative to individual element in B**.
#
#   - For example, if A is a scalar, B is a vector (b1, b2, b3), then the result is a collection of (dA/db1, dA/db2, dA/db3). (ignore the dimension)
#
# - For the direvative of a single element (L) to another single element (w_ij), use this chain rule
# ![Screenshot 2025-08-03 at 12.01.40 PM.png](data:image/png;base64,...)

# %% [markdown]
# The diagram of the network used in the section is shown below
#
# ![](https://raw.githubusercontent.com//lizhieffe/llm_knowledge/main/derivations/yt_backprop_network_diagram.png)

# %% [markdown]
# Good reads
# - https://www.youtube.com/watch?v=x4RNPJD-IkQ&ab_channel=MeerkatStatistics

# %% [markdown]
# Notations for the derivations
#
# - x is the **input** to the whole network. Shape = (1, lx); e.g. (1, 2).
# - w is the **weight** of the linear layer. Shape = (lw1, lw2)
# - a is the **activation** from the hidden layers. Shape = (1, la)
# - sigma is the **activation fn**, e.g. sigmoid.

# %% [markdown]
# ### 1. Chain Rule

# %% [markdown]
# ![Screenshot 2025-08-03 at 10.46.45 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. The derivative of the Loss (scalar) w.r.t. something (e.g. matrix) will always be the **same shape** as that something.

# %% [markdown]
# ![Screenshot 2025-08-03 at 10.49.37 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### 3. Element-wise operations => **Same shape** derivative => element-wise chain rule (Hadamard product)

# %% [markdown]
# ![Screenshot 2025-08-03 at 10.50.20 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### 4. The derivate of the input to the linear layer is the transpose of the weight
#
# - The input can either be x (original input to the network), or a (activation from the previous layer)
#
# Tip: Think this way
# - In backprop, it needs to project back

# %% [markdown]
# My proof:
#
# ![](https://raw.githubusercontent.com//lizhieffe/llm_knowledge/main/derivations/proof_backprop_derivate_to_input_or_activation.png)

# %% [markdown]
# ![Screenshot 2025-08-03 at 10.59.07 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### 5. The derivative of the weight to the linear layer is the **outer product** of the input (x, or a) and the backprop value to this point.
#
# Note about **inner product** & **outer product**
#
# - The inner product (also known as the dot product) and outer product are two fundamental operations in linear algebra that involve multiplying **two vectors**. The inner product results in a scalar (a single number), while the outer product results in a matrix.

# %% [markdown]
# My proof:
#
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_backprop_derivate_to_weight.png)

# %% [markdown]
# YT proof:
#
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_backprop_derivate_to_weight_1.png)
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_backprop_derivate_to_weight_2.png)
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_backprop_derivate_to_weight_3.png)
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_backprop_derivate_to_weight_4.png)

# %% [markdown]
# ### 6. The derivative of a vector to itself is I (identity matrix)

# %% [markdown]
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_backprop_derivate_to_itself.png)

# %% [markdown]
# ## Example

# %% [markdown]
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/example_backprop_1.png)
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/example_backprop_2.png)
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/example_backprop_3.png)

# %% [markdown]
# ## How to handle batch dim?
#
# TODO: https://www.youtube.com/watch?v=JsbFBJCWbeI&ab_channel=MeerkatStatistics

# %% [markdown]
# ![](https://raw.githubusercontent.com/lizhieffe/llm_knowledge/main/derivations/proof_yt_handle_batch.png)

# %% [markdown]
# ## How to handle more layers
#
# TODO: https://www.youtube.com/watch?v=JsbFBJCWbeI&ab_channel=MeerkatStatistics
